# %% [markdown]
# ### ALWAYS RESTART THE NOTEBOOK AFTER MODIFYING CONFIG.PY

# %%
import dodo
import config


import load_0dte
from tools_nl import *

# %% [markdown]
# ## Load Test Data

# %%
DATA_DIR = config.DATA_DIR
CSV_FILE = config.CSV_FILE

df_def = load_0dte.load_clean(DATA_DIR, CSV_FILE, dte_= 1)
df_def.head()
# Out:
#   ticker   tradeDate   expirDate  dte  strike   stockPrice  callVolume  \
# 0    SPX  2024-03-13  2024-03-13    1  1400.0  5176.490381         0.0
# 1    SPX  2024-03-13  2024-03-13    1  1600.0  5176.490381         0.0
# 2    SPX  2024-03-13  2024-03-13    1  1800.0  5176.490381         0.0
# 3    SPX  2024-03-13  2024-03-13    1  2000.0  5176.490381         2.0
# 4    SPX  2024-03-13  2024-03-13    1  2200.0  5176.490381         0.0
#
#    callOpenInterest  callBidSize  callAskSize  ...  extCallValue  extPutValue  \
# 0               0.0         15.0          2.0  ...   3776.490381          0.0
# 1               0.0          7.0          1.0  ...   3576.490381          0.0
# 2               1.0         15.0          2.0  ...   3376.490381          0.0
# 3              12.0         16.0          7.0  ...   3176.490381          0.0
# 4               0.0          7.0          1.0  ...   2976.490381          0.0
#
# ...

# %%
df_def.shape
# Out:
# (68982, 48)

# %%
# Change the csv file name and dte to analyze another day's data
df3_27 = load_0dte.load_clean(csv_file_= '3_27_data.csv')

df3_27.head()
# Out:
#   ticker   tradeDate   expirDate  dte  strike   stockPrice  callVolume  \
# 0    SPX  2024-03-27  2024-03-27    1  1400.0  5236.766423         0.0
# 1    SPX  2024-03-27  2024-03-27    1  1600.0  5236.766423         0.0
# 2    SPX  2024-03-27  2024-03-27    1  1800.0  5236.766423         0.0
# 3    SPX  2024-03-27  2024-03-27    1  2000.0  5236.766423         3.0
# 4    SPX  2024-03-27  2024-03-27    1  2200.0  5236.766423         0.0
#
#    callOpenInterest  callBidSize  callAskSize  ...  extCallValue  extPutValue  \
# 0            2799.0          1.0          1.0  ...   3836.766423          0.0
# 1               0.0          1.0          1.0  ...   3636.766423          0.0
# 2               0.0          1.0          1.0  ...   3436.766423          0.0
# 3               2.0          1.0          1.0  ...   3236.766423          0.0
# 4               1.0          1.0          1.0  ...   3036.766423          0.0
#
# ...

# %%
df3_27.shape
# Out:
# (69019, 48)

# %% [markdown]
# ## Start Analysis (October 30th 2023 - April 4th 2024)
